# %%
import numpy as np
import scipy as sp

# %%
m = 1230
sigma = 200
n = 1000
alpha = 0.05
beta = 0.1

ppf1 = sp.stats.norm.ppf(1 - alpha/2)
ppf2 = sp.stats.norm.ppf(1 - beta)
e_min = np.sqrt( (ppf1 + ppf2)**2 * (sigma**2 + sigma**2) / n )
e_min
# Out:
# np.float64(28.992996480447644)
